# %% [markdown]
# <a href="https://colab.research.google.com/github/Samruddhi-273/SOC-repo/blob/master/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Load Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-0d58b620-89bb-4270-af8d-a44d3cff4645" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d58b620-89bb-4270-af8d-a44d3cff4645">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Inspect Dataset

# %%
df = pd.read_csv("titanic.csv")

# %%
df.head()
# Out:
#    PassengerId                                               Name  Pclass  \
# 0            1                            Braund, Mr. Owen Harris       3
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 2            3                             Heikkinen, Miss. Laina       3
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 4            5                           Allen, Mr. William Henry       3
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S
#
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
df.tail()
# Out:
#      PassengerId                                      Name  Pclass     Sex  \
# 886          887                     Montvila, Rev. Juozas       2    male
# 887          888              Graham, Miss. Margaret Edith       1  female
# 888          889  Johnston, Miss. Catherine Helen "Carrie"       3  female
# 889          890                     Behr, Mr. Karl Howell       1    male
# 890          891                       Dooley, Mr. Patrick       3    male
#
#       Age  SibSp  Parch      Ticket   Fare Cabin Embarked  Survived
# 886  27.0      0      0      211536  13.00   NaN        S         0
# 887  19.0      0      0      112053  30.00   B42        S         1
# 888   NaN      1      2  W./C. 6607  23.45   NaN        S         0
# 889  26.0      0      0      111369  30.00  C148        C         1
# 890  32.0      0      0      370376   7.75   NaN        Q         0

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Name', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'Survived'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Name         891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Sex          891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Embarked     889 non-null    object
#  11  Survived     891 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   891.000000  891.000000  714.000000  891.000000  891.000000
# mean    446.000000    2.308642   29.699118    0.523008    0.381594
# std     257.353842    0.836071   14.526497    1.102743    0.806057
# min       1.000000    1.000000    0.420000    0.000000    0.000000
# 25%     223.500000    2.000000   20.125000    0.000000    0.000000
# 50%     446.000000    3.000000   28.000000    0.000000    0.000000
# 75%     668.500000    3.000000   38.000000    1.000000    0.000000
# max     891.000000    3.000000   80.000000    8.000000    6.000000
#
#              Fare    Survived
# count  891.000000  891.000000
# mean    32.204208    0.383838
# std     49.693429    0.486592
# min      0.000000    0.000000
# 25%      7.910400    0.000000
# 50%     14.454200    0.000000
# 75%     31.000000    1.000000
# max    512.329200    1.000000

# %% [markdown]
# Missing Values

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Name             0
# Pclass           0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# Survived         0
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# PassengerId     0.000000
# Name            0.000000
# Pclass          0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# Survived        0.000000
# dtype: float64

# %%
df["Age"].fillna(df["Age"].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
df["Age"].fillna(df["Age"].median())
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df["Fare"].fillna(df["Fare"].mode()[0])
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df.dropna()
# Out:
#      PassengerId                                               Name  Pclass  \
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1
# 6              7                            McCarthy, Mr. Timothy J       1
# 10            11                    Sandstrom, Miss. Marguerite Rut       3
# 11            12                           Bonnell, Miss. Elizabeth       1
# ..           ...                                                ...     ...
# 871          872   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)       1
# 872          873                           Carlsson, Mr. Frans Olof       1
# 879          880      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)       1
# 887          888                       Graham, Miss. Margaret Edith       1
# 889          890                              Behr, Mr. Karl Howell       1
#
# ...

# %% [markdown]
# Data Types

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())
df["Age"] = df["Age"].astype(int)

# %% [markdown]
# Statistics

# %%
df["Age"].mean()
# Out:
# np.float64(29.34567901234568)

# %%
df["Age"].median()
# Out:
# 28.0

# %%
df["Age"].mode()
# Out:
# 0    28
# Name: Age, dtype: int64

# %%
df["Age"].max()
# Out:
# 80

# %%
df["Age"].min()
# Out:
# 0

# %%
df["Age"].std()
# Out:
# 13.028211862792078

# %% [markdown]
# GroupBy

# %%
df.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    27.920382
# male      30.121317
# Name: Age, dtype: float64

# %% [markdown]
# Histogram

# %%
sns.histplot(df["Age"],bins=20,kde=True)
plt.show()

# %% [markdown]
# Boxplot

# %%
sns.boxplot(y=df["Age"])
plt.show()

# %% [markdown]
# Scatter Plot

# %%
sns.scatterplot(data=df,x="Age",y="Fare")
plt.show()

# %% [markdown]
# Heatmap

# %%
numeric_df = df.select_dtypes(include=[np.number])
sns.heatmap(numeric_df.corr(), annot=True)
plt.show()

# %% [markdown]
# Pairplot

# %%
sns.pairplot(df)

# %% [markdown]
# Line Plot

# %%
sns.lineplot(data=df.groupby('Pclass')['Fare'].mean().reset_index(), x='Pclass', y='Fare')
plt.show()

# %% [markdown]
# Outlier Detection

# %%
Q1=df["Age"].quantile(0.25)

Q3=df["Age"].quantile(0.75)

IQR=Q3-Q1

lower=Q1-1.5*IQR

upper=Q3+1.5*IQR

outliers=df[(df["Age"]<lower)|(df["Age"]>upper)]

# %%
from scipy.stats import zscore

df["z"]=zscore(df["Age"])

# %%
df[df["z"].abs()>3]
# Out:
#      PassengerId                                  Name  Pclass   Sex  Age  \
# 96            97             Goldschmidt, Mr. George B       1  male   71
# 116          117                  Connors, Mr. Patrick       3  male   70
# 493          494               Artagaveytia, Mr. Ramon       1  male   71
# 630          631  Barkworth, Mr. Algernon Henry Wilson       1  male   80
# 672          673           Mitchell, Mr. Henry Michael       2  male   70
# 745          746          Crosby, Capt. Edward Gifford       1  male   70
# 851          852                   Svensson, Mr. Johan       3  male   74
#
#      SibSp  Parch      Ticket     Fare Cabin Embarked  Survived         z
# 96       0      0    PC 17754  34.6542    A5        C         0  3.199036
# 116      0      0      370369   7.7500   NaN        Q         0  3.122236
# 493      0      0    PC 17609  49.5042   NaN        C         0  3.199036
# 630      0      0       27042  30.0000   A23        S         1  3.890232
# ...

# %% [markdown]
# Corelation

# %%
numeric_df.corr()
# Out:
#              PassengerId    Pclass       Age     SibSp     Parch      Fare  \
# PassengerId     1.000000 -0.035144  0.034322 -0.057527 -0.001652  0.012658
# Pclass         -0.035144  1.000000 -0.339999  0.083081  0.018443 -0.549500
# Age             0.034322 -0.339999  1.000000 -0.233066 -0.172745  0.096838
# SibSp          -0.057527  0.083081 -0.233066  1.000000  0.414838  0.159651
# Parch          -0.001652  0.018443 -0.172745  0.414838  1.000000  0.216225
# Fare            0.012658 -0.549500  0.096838  0.159651  0.216225  1.000000
# Survived       -0.005007 -0.338481 -0.064909 -0.035322  0.081629  0.257307
#
#              Survived
# PassengerId -0.005007
# Pclass      -0.338481
# Age         -0.064909
# SibSp       -0.035322
# Parch        0.081629
# Fare         0.257307
# Survived     1.000000

# %% [markdown]
# Feature Engineering

# %%
bins=[0,18,60,100]

labels=["Child","Adult","Senior"]

df["Age_Group"]=pd.cut(df["Age"],bins=bins,labels=labels)

# %%
from scipy.stats import ttest_ind

group1 = df[df['Survived'] == 0]['Age']
group2 = df[df['Survived'] == 1]['Age']

t, p = ttest_ind(group1, group2)
