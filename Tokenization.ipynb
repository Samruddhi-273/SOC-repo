# %% [markdown]
# <a href="https://colab.research.google.com/github/Samruddhi-273/SOC-repo/blob/master/Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentence = "IIT Bombay is amazing"

# %%
tokens = sentence.split()

print(tokens)
# Out:
# ['IIT', 'Bombay', 'is', 'amazing']

# %%
text = "Samruddhi"

# %%
tokens = list(text)

print(tokens)
# Out:
# ['S', 'a', 'm', 'r', 'u', 'd', 'd', 'h', 'i']
