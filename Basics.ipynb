# %% [markdown]
# <a href="https://colab.research.google.com/github/Samruddhi-273/SOC-repo/blob/master/Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")
word = 'samruddhi'
print(word)
print("Hello World" + ' ' + word) #concatenate
# Out:
# Hello World
# samruddhi
# Hello World samruddhi

# %%
name = "Samruddhi"
age = 20
height = 154

print(name) #Basic printing
print(age)
print(height)
# Out:
# Samruddhi
# 20
# 154
