# %% [markdown]
# <a href="https://colab.research.google.com/github/Samruddhi-273/SOC-repo/blob/master/WordPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = "My name is Samruddhi"

words = text.split()

# %%
for i in range(len(words)-1):
    print(words[i], "->", words[i+1])
# Out:
# My -> name
# name -> is
# is -> Samruddhi
